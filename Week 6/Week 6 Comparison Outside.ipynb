# %%
import numpy as np
import pandas as pd 
import csv
from pathlib import Path
import matplotlib.pyplot as plt

home_dir = Path.home()
#print(home_dir)

# %%
inside_file = 'Weather_AQI_inside5.csv'
outside_file = 'Weather_AQI_outside5.csv'
their_outside_file = 'others_outsidedata.csv' 
outside_2_file = 'outsideweek6.csv'

# %%
dfinside = pd.read_csv(inside_file)
dfoutside = pd.read_csv(outside_file)
their_outside = pd.read_csv(their_outside_file)
#display(dfinside)
useful_inside = dfinside[1:]
useful_outside = dfoutside[1:]
useful_their_outside = their_outside[1:]
display(useful_outside)
display(useful_their_outside)
week6_outside = pd.read_csv(outside_2_file)
useful_week6 = week6_outside[1:]
display(useful_week6)
# Out:
#              Time       Temp     Gas   Humidity     Pressure        Alt  \
# 1    1.740179e+09  22.590742   15613  34.694782  1009.205809  33.725191
# 2    1.740179e+09  22.637031   29428  34.613338  1009.208623  33.701686
# 3    1.740179e+09  22.675117   43357  34.485446  1009.210464  33.686316
# 4    1.740179e+09  22.700312   55212  34.362157  1009.205497  33.727797
# 5    1.740179e+09  22.722188   66114  34.250060  1009.209241  33.696524
# ..            ...        ...     ...        ...          ...        ...
# 295  1.740180e+09  18.484883  180481  42.237444  1009.163778  34.076275
# 296  1.740180e+09  18.485078  178194  42.297161  1009.160595  34.102858
# 297  1.740180e+09  18.486055  178383  42.327122  1009.160436  34.104191
# 298  1.740180e+09  18.491719  179330  42.375506  1009.166162  34.056362
# 299  1.740180e+09  18.497969  180288  42.417993  1009.167591  34.044423
#
#      PM 1.0  PM 2.5  PM 10
# 1         1       2      2
# 2         1       2      2
# ...

# %% [markdown]
# PM 1.0:

# %%
plt.hist(useful_week6['PM 1.0'],bins = 3,alpha=0.5)
plt.hist(useful_outside['PM 1.0'],bins=3,alpha=0.5)
plt.xlabel("counts per second")
plt.ylabel('frequency')
plt.title('PM 1.0 counts')
plt.show()

# %%
outside_PM1_mean = np.mean(useful_outside['PM 1.0'])
week6_outside_PM1_mean = np.mean(useful_week6['PM 1.0'])
outside_PM1_std = np.std(useful_outside['PM 1.0'])
week6_outside_PM1_std = np.std(useful_week6['PM 1.0'])
print('a)\n')
print('Our mean uncertainty is {:.4f}'.format(outside_PM1_std/np.sqrt(len(useful_outside['PM 1.0']))))
print('week6 mean uncertainty is {:.4f}'.format(week6_outside_PM1_std/np.sqrt(len(useful_week6['PM 1.0']))))
print('\nb)\n')
print('The means are separated by {:.2f} of our standard deviation'.format(np.abs((outside_PM1_mean-week6_outside_PM1_mean)/(outside_PM1_std/np.sqrt(len(useful_outside['PM 1.0']))))))
print('\nc)\n')
print('There are not enough data points for a gaussian')
# Out:
# a)
#
# Our mean uncertainty is 0.0306
# week6 mean uncertainty is 0.0958
#
# b)
#
# The means are separated by 280.21 of our standard deviation
#
# c)
#
# There are not enough data points for a gaussian

# %% [markdown]
# PM 2.5:

# %%
plt.hist(useful_week6['PM 2.5'],bins = 3,alpha=0.5)
plt.hist(useful_outside['PM 2.5'],bins=3,alpha=0.5)
plt.xlabel("counts per second")
plt.ylabel('frequency')
plt.title('PM 2.5 counts')
plt.show()

# %%
outside_PM25_mean = np.mean(useful_outside['PM 2.5'])
week6_outside_PM25_mean = np.mean(useful_week6['PM 2.5'])
outside_PM25_std = np.std(useful_outside['PM 2.5'])
week6_outside_PM25_std = np.std(useful_week6['PM 2.5'])
print('a)\n')
print('Our mean uncertainty is {:.4f}'.format(outside_PM25_std/np.sqrt(len(useful_outside['PM 2.5']))))
print('week6 mean uncertainty is {:.4f}'.format(week6_outside_PM25_std/np.sqrt(len(useful_week6['PM 2.5']))))
print('\nb)\n')
print('The means are separated by {:.2f} of our standard deviation'.format(np.abs((outside_PM25_mean-week6_outside_PM25_mean)/(outside_PM25_std/np.sqrt(len(useful_outside['PM 2.5']))))))
print('\nc)\n')
print('There are not enough data points for a gaussian')
# Out:
# a)
#
# Our mean uncertainty is 0.0327
# week6 mean uncertainty is 0.1518
#
# b)
#
# The means are separated by 371.43 of our standard deviation
#
# c)
#
# There are not enough data points for a gaussian

# %% [markdown]
# PM 10:

# %%
plt.hist(useful_week6['PM 10'],bins = 3,alpha=0.5)
plt.hist(useful_outside['PM 10'],bins=3,alpha=0.5)
plt.xlabel("counts per second")
plt.ylabel('frequency')
plt.title('PM 10 counts')
plt.show()

# %%
outside_PM10_mean = np.mean(useful_outside['PM 10'])
week6_outside_PM10_mean = np.mean(useful_week6['PM 10'])
outside_PM10_std = np.std(useful_outside['PM 10'])
week6_outside_PM10_std = np.std(useful_week6['PM 10'])
print('a)\n')
print('Our mean uncertainty is {:.4f}'.format(outside_PM10_std/np.sqrt(len(useful_outside['PM 10']))))
print('week6 mean uncertainty is {:.4f}'.format(week6_outside_PM10_std/np.sqrt(len(useful_week6['PM 10']))))
print('\nb)\n')
print('The means are separated by {:.2f} of our standard deviation'.format(np.abs((outside_PM10_mean-week6_outside_PM10_mean)/(outside_PM10_std/np.sqrt(len(useful_week6['PM 10']))))))
print('\nc)\n')
print('There are not enough data points for a gaussian')
# Out:
# a)
#
# Our mean uncertainty is 0.0416
# week6 mean uncertainty is 0.1791
#
# b)
#
# The means are separated by 311.11 of our standard deviation
#
# c)
#
# There are not enough data points for a gaussian

# %% [markdown]
# Temp:

# %%
plt.hist(useful_week6['Temp'],bins = 30,alpha=0.5)
plt.hist(useful_outside['Temp'],bins=30,alpha=0.5)
plt.xlabel("temp [C]")
plt.ylabel('frequency')
plt.title('temp [C]')
plt.show()

# %%
outside_temp_mean = np.mean(useful_outside['Temp'])
week6_outside_temp_mean = np.mean(useful_week6['Temp'])
outside_temp_std = np.std(useful_outside['Temp'])
week6_outside_temp_std = np.std(useful_week6['Temp'])
print('a)\n')
print('Our mean uncertainty is {:.4f}'.format(outside_temp_std/np.sqrt(len(useful_outside['Temp']))))
print('week6 mean uncertainty is {:.4f}'.format(week6_outside_temp_std/np.sqrt(len(useful_week6['Temp']))))
print('\nb)\n')
print('The means are separated by {:.2f} of our standard deviation'.format(np.abs((outside_temp_mean-week6_outside_temp_mean)/(outside_temp_std/np.sqrt(len(useful_week6['Temp']))))))
print('\nc)\n')
print('it looks kind of close to a gaussian.... probably enough data points')
# Out:
# a)
#
# Our mean uncertainty is 0.0625
# week6 mean uncertainty is 0.0188
#
# b)
#
# The means are separated by 59.91 of our standard deviation
#
# c)
#
# it looks kind of close to a gaussian.... probably enough data points

# %% [markdown]
# Altitude:

# %%
plt.hist(useful_week6['Alt'],bins = 30,alpha=0.5)
plt.hist(useful_outside['Alt'],bins=30,alpha=0.5)
plt.xlabel("altitude[m]")
plt.ylabel('frequency')
plt.title('Altitude [m]')
plt.show()

# %%
outside_alt_mean = np.mean(useful_outside['Alt'])
week6_outside_alt_mean = np.mean(useful_week6['Alt'])
outside_alt_std = np.std(useful_outside['Alt'])
week6_outside_alt_std = np.std(useful_week6['Alt'])
print('a)\n')
print('Our mean uncertainty is {:.4f}'.format(outside_alt_std/np.sqrt(len(useful_outside['Alt']))))
print('week6 mean uncertainty is {:.4f}'.format(week6_outside_alt_std/np.sqrt(len(useful_week6['Alt']))))
print('\nb)\n')
print('The means are separated by {:.2f} of our standard deviation'.format(np.abs((outside_alt_mean-week6_outside_alt_mean)/(outside_alt_std/np.sqrt(len(useful_week6['Alt']))))))
print('\nc)\n')
print('too far away to tell if it is gaussian')
# Out:
# a)
#
# Our mean uncertainty is 0.0107
# week6 mean uncertainty is 0.0191
#
# b)
#
# The means are separated by 6654.59 of our standard deviation
#
# c)
#
# too far away to tell if it is gaussian

# %% [markdown]
# Humididty:

# %%
plt.hist(useful_week6['Humidity'],bins = 30,alpha=0.5)
plt.hist(useful_outside['Humidity'],bins=30,alpha=0.5)
plt.xlabel("Humidity")
plt.ylabel('frequency')
plt.title('Humidity')
plt.show()

# %%
outside_hum_mean = np.mean(useful_outside['Humidity'])
week6_outside_hum_mean = np.mean(useful_week6['Humidity'])
outside_hum_std = np.std(useful_outside['Humidity'])
week6_outside_hum_std = np.std(useful_week6['Humidity'])
print('a)\n')
print('Our mean uncertainty is {:.4f}'.format(outside_hum_std/np.sqrt(len(useful_outside['Humidity']))))
print('week6 mean uncertainty is {:.4f}'.format(week6_outside_hum_std/np.sqrt(len(useful_week6['Humidity']))))
print('\nb)\n')
print('The means are separated by {:.2f} of our standard deviation'.format(np.abs((outside_hum_mean-week6_outside_hum_mean)/(outside_hum_std/np.sqrt(len(useful_week6['Humidity']))))))
print('\nc)\n')
print('Both are Bimodal, sugesting an error in our measurement methods.')
# Out:
# a)
#
# Our mean uncertainty is 0.1252
# week6 mean uncertainty is 0.0848
#
# b)
#
# The means are separated by 45.97 of our standard deviation
#
# c)
#
# Both are Bimodal, sugesting an error in our measurement methods.

# %% [markdown]
# Pressure:

# %%
plt.hist(useful_week6['Pressure'],bins = 30,alpha=0.5)
plt.hist(useful_outside['Pressure'],bins=30,alpha=0.5)
plt.xlabel("Pressure")
plt.ylabel('frequency')
plt.title('Pressure')
plt.show()

# %%
outside_pressure_mean = np.mean(useful_outside['Pressure'])
week6_outside_pressure_mean = np.mean(useful_week6['Pressure'])
outside_pressure_std = np.std(useful_outside['Pressure'])
week6_outside_pressure_std = np.std(useful_week6['Pressure'])
print('a)\n')
print('Our mean uncertainty is {:.4f}'.format(outside_pressure_std/np.sqrt(len(useful_outside['Pressure']))))
print('week6 mean uncertainty is {:.4f}'.format(week6_outside_pressure_std/np.sqrt(len(useful_week6['Pressure']))))
print('\nb)\n')
print('The means are separated by {:.2f} of our standard deviation'.format(np.abs((outside_pressure_mean-week6_outside_pressure_mean)/(outside_pressure_std/np.sqrt(len(useful_week6['Pressure']))))))
print('\nc)\n')
print('too far apart to tell if it is gaussian')
# Out:
# a)
#
# Our mean uncertainty is 0.0013
# week6 mean uncertainty is 0.0023
#
# b)
#
# The means are separated by 6631.84 of our standard deviation
#
# c)
#
# too far apart to tell if it is gaussian
