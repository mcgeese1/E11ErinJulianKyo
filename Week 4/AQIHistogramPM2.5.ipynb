# %%
import matplotlib.pyplot as plt
import csv
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('pm25data.csv')
display(df)
# Out:
#     PM 1.0  PM 2.5  PM 10
# 0        0       1      2
# 1        0       1      3
# 2        0       1      3
# 3        0       1      3
# 4        0       1      3
# 5        0       1      3
# 6        0       1      3
# 7        0       2      3
# 8        0       2      3
# 9        0       2      3
# 10       0       2      4
# 11       0       2      4
# 12       0       2      4
# 13       0       3      4
# 14       0       3      4
# 15       0       3      4
# 16       0       3      4
# 17       0       3      4
# 18       0       3      4
# 19       0       3      4
# 20       0       3      4
# 21       0       3      4
# 22       0       3      5
# 23       0       3      5
# 24       0       3      5
# 25       0       4      5
# 26       0       4      5
# 27       0       4      5
# 28       0       4      4
# 29       0       4      4
# 30       0       4      4

# %%
fig = plt.hist(df["PM 2.5"],bins=4)
plt.xlabel("Counts/Sec")
plt.title("PM 2.5 Microns") 
plt.ylabel("Frequency")
plt.show()

# %%
fig2 = plt.plot(df["PM 2.5"])

# %% [markdown]
# It is interesting that when you plot the time series for the data, the counts per second is increasing. While we were collecting the data we all came close to the sensor, so that may be the reason for it.
